# %% [markdown]
# # Pandas

# %%
# !pip3 install pandas
# !pip3 install pandas
import sys
# !{sys.executable} -m ensurepip --upgrade
# !{sys.executable} -m pip install pandas
import sys

print(sys.version)          # shows Python version
print(sys.path)             # shows all importable paths
print(sys.platform)         # tells OS (e.g., 'darwin' for macOS)
print(sys.argv)             # command line args (in scripts)


#openpyxl is a Python library used for:
#	•	Reading and writing Excel .xlsx files.
# !pip3 install openpyxl
# Out:
# ...
# Looking in links: /var/folders/73/8f3xzr29369gjrn1m6_qtjw80000gn/T/tmpj_ap0acd
# ...
# 3.13.2 (v3.13.2:4f8bb3947cf, Feb  4 2025, 11:51:10) [Clang 15.0.0 (clang-1500.3.9.4)]
# ['/Library/Frameworks/Python.framework/Versions/3.13/lib/python313.zip', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/lib-dynload', '', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages']
# darwin
# ['/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/ipykernel_launcher.py', '--f=/Users/user/Library/Jupyter/runtime/kernel-v316c1b1f3a6f543a6509d29711bf4f73697dc974a.json']
# ...

# %% [markdown]
# # Testing Pandas is Running or Not

# %%
import pandas as pd

# Create test data using dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 22],
    'City': ['Kolkata', 'Mumbai', 'Delhi']
}

# Convert dictionary to DataFrame
df = pd.DataFrame(data)

# Show the DataFrame
print(df)

# Access a column
print("Names:\n", df['Name'])

# Filter rows where Age > 23
print("Age > 23:\n", df[df['Age'] > 23])
# Out:
#       Name  Age     City
# 0    Alice   25  Kolkata
# 1      Bob   30   Mumbai
# 2  Charlie   22    Delhi
# Names:
#  0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object
# Age > 23:
#      Name  Age     City
# 0  Alice   25  Kolkata
# 1    Bob   30   Mumbai

# %%
import pandas as pd
df = pd.DataFrame(
    {
"Name": [
    "Braund , Mr. Owen Harris",
    "Allen, Mr. William Henry",
    "Bonnell, Miss. Elizabeth",
],
"Age": [
    22,
    35,
    58
],
"Sex": ["male", "male", "female"],

    })
df
df.head()  # Display the first few rows of the DataFrame
df.tail()  # Display the last few rows of the DataFrame
# df["Age"]

# df.info()



#When selecting a single column of a pandas DataFrame, the result is a pandas Series. To select the column, use the
#column label in between square brackets [].
ages = pd.Series([20, 10, 11], name="Age")
ages
df["Age"].max()  # Get the maximum age
df["Age"].min() # Get the minimum age
ages.max()  # Get the maximum ages from the Series

df.describe()  # Get a summary of statistics for the DataFrame
# Out:
#              Age
# count   3.000000
# mean   38.333333
# std    18.230012
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    46.500000
# max    58.000000

# %% [markdown]
# # Titanic Data Set
# Caution -> the Dataset of Titanic is Not toally clean atall ....

# %%
import pandas as pd
titanic = pd.read_csv("/Users/user/Desktop/Developer/jupyter/Pandas/Titanic-Dataset.csv")

titanic.columns = titanic.columns.str.strip().str.lower()  #	3.	.strip()
#➤ Removes unwanted leading and trailing spaces in the column names.
#Example: " Age " → "Age"
titanic["age"] = pd.to_numeric(titanic["age"], errors="coerce")  # Convert "Age" to numeric, Bhai errors="coerce" ka matlab hai : “Jo values number me convert nahi ho sakti, unhe NaN (Not a Number) bana do, taaki column numeric ban sake.”


# titanic.head()  # Display the first few rows of the Titanic dataset
titanic
titanic.head(8)

titanic.describe()  # Get a summary of statistics for the Titanic dataset
titanic.info()  # Get information about the DataFrame, including data types and non
titanic.tail()

#  The Titanic data as a spreadsheet.
titanic.to_excel("titanic.xlsx", sheet_name="passengers", index=False)
titanic = pd.read_excel("titanic.xlsx", sheet_name="passengers")
titanic.info()


# If i want to check ages among these passengers
ages = titanic["age"]
ages
ages.head()
titanic.dtypes # Display the data types of each column

type(titanic["age"]) # Check the type of the "Age" column    pandas.core.series.Series

titanic["age"].max()
titanic["age"].shape # Get the number of elements in the "Age" column (891,)




above_35 = titanic[titanic["age"]>35]
above_35.head()

titanic["age"] > 35


# print(titanic.index.tolist())
titanic["age"].head()
titanic[titanic["age"].isna()]  # Display rows where "Age" is NaN (missing values)
# if want to see the unknown passengers age then 
# titanic.rename(columns={"age": "Age"}, inplace=True)  # Rename the "age" column to "Age"

class_23 = titanic[titanic["pclass"].isin([2, 3])]  # Filter passengers in classes 2 and 3
print(class_23.head())
print(titanic['pclass'].unique())
# print(titanic.columns.tolist())

class_23 = titanic[(titanic["pclass"] == 2) | (titanic["pclass"] == 3)]
print(titanic["pclass"].unique())

age_no_na = titanic[titanic["age"].notna()]  # Filter rows where "Age" is not NaN
print("Paasengers with unkwown age:\n")
for age1 in age_no_na:
    print(age1) # age_no_na.shape


# I’m interested in the names of the passengers older than 35 years.
adults_name = titanic.loc[titanic["age"] > 35, "name"]   #.loc[] is used to access a group of rows and columns by labels or boolean arrays.
print("These are older than 35: \n")  # Display names of passengers older than 35 years

# Or if i want to show these 35 years older passengers via for loop it looks like this 
for name in adults_name:
    print(name)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    object
#  3   name         891 non-null    object
#  4   sex          891 non-null    object
#  5   age          714 non-null    float64
#  6   sibsp        891 non-null    int64
#  7   parch        891 non-null    int64
#  8   ticket       891 non-null    object
#  9   fare         891 non-null    float64
#  10  cabin        891 non-null    object
#  11  embarked     891 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 90.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
# In this case, a subset of both rows and columns is made in one go and just using selection brackets [] is not sufficient
# anymore. The loc/iloc operators are required in front of the selection brackets []. When using loc/iloc, the part
# before the comma is the rows you want, and the part after the comma is the columns you want to select.
# When using the column names, row labels or a condition expression, use the loc operator in front of the selection
# brackets []. For both the part before and after the comma, you can use a single label, a list of labels, a slice of labels,
# a conditional expression or a colon. Using a colon specifies you want to select all rows or columns.



# I’m interested in rows 10 till 25 and columns 3 to 5.


titanic.iloc[9:25 , 2:5]

# titanic.iloc[0:3, 3]

# titanic.head()
# titanic.head().shape
# Out:
#              pclass                                               name  \
# 9           "Nasser   Mrs. Nicholas (Adele Achem)"                 ...
# 10       "Sandstrom   Miss. Marguerite Rut"                        ...
# 11         "Bonnell   Miss. Elizabeth"                             ...
# 12     "Saundercock   Mr. William Henry"                           ...
# 13       "Andersson   Mr. Anders Johan"                            ...
# 14         "Vestrom   Miss. Hulda Amanda Adolfina"                 ...
# 15         "Hewlett   Mrs. (Mary D Kingcome) "                     ...
# 16            "Rice   Master. Eugene"                              ...
# 17        "Williams   Mr. Charles Eugene"                          ...
# 18   "Vander Planke   Mrs. Julius (Emelia Maria Vandemoortele)"    ...
# 19      "Masselmani   Mrs. Fatima"                                 ...
# 20          "Fynney   Mr. Joseph J"                                ...
# ...
